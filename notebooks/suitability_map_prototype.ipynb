# %% [markdown]
# # Jonglei Suitability Prototype
#
# This notebook is a sandbox for computing FHI/SVI components and exporting rasters for the app.

# %%
import numpy as np

fhi = np.random.rand(10, 10)
svi = np.random.rand(10, 10)
suitability = 0.6 * fhi + 0.4 * svi
suitability[:2, :2]
